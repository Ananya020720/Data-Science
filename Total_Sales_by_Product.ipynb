# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya020720/Data-Science/blob/main/Total_Sales_by_Product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Group by Product Category and find total revenue generated by each.

import pandas as pd

df = pd.read_csv('sales_data.csv')
total_revenue = df.groupby('Product Category')['Total Revenue'].sum()
print(total_revenue)
# Out:
# Product Category
# Beauty Products     2621.90
# Books               1861.93
# Clothing            8128.93
# Electronics        34982.41
# Home Appliances    18646.16
# Sports             14326.52
# Name: Total Revenue, dtype: float64

# %% [markdown]
# # New Section
